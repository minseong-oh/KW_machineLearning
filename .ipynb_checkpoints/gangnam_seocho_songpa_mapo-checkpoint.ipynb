# %% [markdown]
# # 견인 다수 지역(강남구, 서초구, 송파구)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pycaret.classification import *
from sklearn.utils import resample
from sklearn.metrics import confusion_matrix
import shap

# %%
df = pd.read_csv("seoul_preprocessed.csv")
print(df.shape)
# Out:
# (44090, 31)

# %%
selected_gu = ["강남구", "서초구", "송파구"]
target_gu = ['마포구']
train_df = df[df["SIG_KOR_NM"].isin(selected_gu)]
test_df = df[df["SIG_KOR_NM"].isin(target_gu)]

# %%
# test를 제외한 데이터로 risk level 추출
df_nonzero = train_df[train_df['tow_count'] > 0]

# `tow_count` 값으로 정렬
df_nonzero = df_nonzero.sort_values(by='tow_count')

total_nonzero = len(df_nonzero)

mid_end = int(total_nonzero*1/2) # 절반

# 각 구간 끝값 (경계)
mid_end_value = df_nonzero.iloc[mid_end - 1]['tow_count']  # 가운데 구간 끝값

print(f"가운데 구간 끝값: {mid_end_value}\n")

train_df['risk_level'] = train_df['tow_count'].apply(
    lambda x: 0 if x == 0 else (1 if x <= mid_end_value else 2)
)

test_df['risk_level'] = test_df['tow_count'].apply(
    lambda x: 0 if x == 0 else (1 if x <= mid_end_value else 2)
)


# 결과 확인
print(train_df[['tow_count', 'risk_level']].tail())
# Out:
# 가운데 구간 끝값: 2
#
#        tow_count  risk_level
# 40621          0           0
# 40622          0           0
# 40623          0           0
# 40624          0           0
# 40625          0           0

# %%
features = train_df.columns[3:-2]
target = 'risk_level'
del train_df['tow_count']
del test_df['tow_count']

# 테스트 데이터 준비
train = train_df.iloc[:,3:]
X_test, y_test   = test_df[features], test_df[target]

# %%
exp_clf = setup(data = train, target = target, session_id=42)
# Out:
# <style type="text/css">
# #T_ed2d3_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ed2d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed2d3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ed2d3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed2d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ed2d3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ed2d3_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ed2d3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ed2d3_row1_col1" class="data row1 col1" >risk_level</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ed2d3_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ed2d3_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ed2d3_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_ed2d3_row3_col1" class="data row3 col1" >(9055, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ed2d3_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_ed2d3_row4_col1" class="data row4 col1" >(9055, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ed2d3_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_ed2d3_row5_col1" class="data row5 col1" >(6338, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ed2d3_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_ed2d3_row6_col1" class="data row6 col1" >(2717, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ed2d3_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_ed2d3_row7_col1" class="data row7 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ed2d3_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_ed2d3_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ed2d3_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_ed2d3_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ed2d3_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_ed2d3_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ed2d3_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_ed2d3_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ed2d3_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_ed2d3_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ed2d3_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_ed2d3_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ed2d3_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_ed2d3_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ed2d3_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_ed2d3_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ed2d3_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_ed2d3_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ed2d3_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_ed2d3_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ed2d3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ed2d3_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_ed2d3_row18_col1" class="data row18 col1" >1872</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_508a7 th {
#   text-align: left;
# }
# #T_508a7_row0_col0, #T_508a7_row0_col2, #T_508a7_row0_col4, #T_508a7_row0_col5, #T_508a7_row0_col6, #T_508a7_row0_col7, #T_508a7_row1_col0, #T_508a7_row1_col1, #T_508a7_row1_col2, #T_508a7_row1_col3, #T_508a7_row1_col4, #T_508a7_row1_col5, #T_508a7_row1_col6, #T_508a7_row1_col7, #T_508a7_row2_col0, #T_508a7_row2_col1, #T_508a7_row2_col3, #T_508a7_row2_col6, #T_508a7_row3_col0, #T_508a7_row3_col1, #T_508a7_row3_col2, #T_508a7_row3_col3, #T_508a7_row3_col4, #T_508a7_row3_col5, #T_508a7_row3_col6, #T_508a7_row3_col7, #T_508a7_row4_col0, #T_508a7_row4_col1, #T_508a7_row4_col2, #T_508a7_row4_col3, #T_508a7_row4_col4, #T_508a7_row4_col5, #T_508a7_row4_col6, #T_508a7_row4_col7, #T_508a7_row5_col0, #T_508a7_row5_col1, #T_508a7_row5_col2, #T_508a7_row5_col3, #T_508a7_row5_col4, #T_508a7_row5_col5, #T_508a7_row5_col6, #T_508a7_row5_col7, #T_508a7_row6_col0, #T_508a7_row6_col1, #T_508a7_row6_col2, #T_508a7_row6_col3, #T_508a7_row6_col4, #T_508a7_row6_col5, #T_508a7_row6_col6, #T_508a7_row6_col7, #T_508a7_row7_col0, #T_508a7_row7_col1, #T_508a7_row7_col2, #T_508a7_row7_col3, #T_508a7_row7_col4, #T_508a7_row7_col5, #T_508a7_row7_col7, #T_508a7_row8_col0, #T_508a7_row8_col1, #T_508a7_row8_col2, #T_508a7_row8_col3, #T_508a7_row8_col4, #T_508a7_row8_col5, #T_508a7_row8_col6, #T_508a7_row8_col7, #T_508a7_row9_col0, #T_508a7_row9_col1, #T_508a7_row9_col2, #T_508a7_row9_col3, #T_508a7_row9_col4, #T_508a7_row9_col5, #T_508a7_row9_col6, #T_508a7_row9_col7, #T_508a7_row10_col0, #T_508a7_row10_col1, #T_508a7_row10_col2, #T_508a7_row10_col3, #T_508a7_row10_col4, #T_508a7_row10_col5, #T_508a7_row10_col6, #T_508a7_row10_col7, #T_508a7_row11_col0, #T_508a7_row11_col1, #T_508a7_row11_col2, #T_508a7_row11_col3, #T_508a7_row11_col4, #T_508a7_row11_col5, #T_508a7_row11_col6, #T_508a7_row11_col7, #T_508a7_row12_col0, #T_508a7_row12_col1, #T_508a7_row12_col2, #T_508a7_row12_col3, #T_508a7_row12_col4, #T_508a7_row12_col5, #T_508a7_row12_col6, #T_508a7_row12_col7, #T_508a7_row13_col0, #T_508a7_row13_col1, #T_508a7_row13_col2, #T_508a7_row13_col3, #T_508a7_row13_col4, #T_508a7_row13_col5, #T_508a7_row13_col6, #T_508a7_row13_col7, #T_508a7_row14_col0, #T_508a7_row14_col1, #T_508a7_row14_col2, #T_508a7_row14_col3, #T_508a7_row14_col4, #T_508a7_row14_col5, #T_508a7_row14_col6, #T_508a7_row14_col7 {
#   text-align: left;
# }
# #T_508a7_row0_col1, #T_508a7_row0_col3, #T_508a7_row2_col2, #T_508a7_row2_col4, #T_508a7_row2_col5, #T_508a7_row2_col7, #T_508a7_row7_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_508a7_row0_col8, #T_508a7_row1_col8, #T_508a7_row2_col8, #T_508a7_row3_col8, #T_508a7_row4_col8, #T_508a7_row6_col8, #T_508a7_row7_col8, #T_508a7_row8_col8, #T_508a7_row9_col8, #T_508a7_row10_col8, #T_508a7_row11_col8, #T_508a7_row12_col8, #T_508a7_row13_col8, #T_508a7_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_508a7_row5_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_508a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_508a7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_508a7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_508a7_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_508a7_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_508a7_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_508a7_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_508a7_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_508a7_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_508a7_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_508a7_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_508a7_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_508a7_row0_col1" class="data row0 col1" >0.8317</td>
#       <td id="T_508a7_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_508a7_row0_col3" class="data row0 col3" >0.8317</td>
#       <td id="T_508a7_row0_col4" class="data row0 col4" >0.7661</td>
#       <td id="T_508a7_row0_col5" class="data row0 col5" >0.7721</td>
#       <td id="T_508a7_row0_col6" class="data row0 col6" >0.1211</td>
#       <td id="T_508a7_row0_col7" class="data row0 col7" >0.1915</td>
#       <td id="T_508a7_row0_col8" class="data row0 col8" >1.9330</td>
#     </tr>
#     <tr>
#       <th id="T_508a7_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_508a7_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_508a7_row1_col1" class="data row1 col1" >0.8309</td>
#       <td id="T_508a7_row1_col2" class="data row1 col2" >0.8101</td>
#       <td id="T_508a7_row1_col3" class="data row1 col3" >0.8309</td>
#       <td id="T_508a7_row1_col4" class="data row1 col4" >0.7566</td>
#       <td id="T_508a7_row1_col5" class="data row1 col5" >0.7746</td>
#       <td id="T_508a7_row1_col6" class="data row1 col6" >0.1404</td>
#       <td id="T_508a7_row1_col7" class="data row1 col7" >0.2020</td>
#       <td id="T_508a7_row1_col8" class="data row1 col8" >0.4380</td>
#     </tr>
#     <tr>
#       <th id="T_508a7_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_508a7_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_508a7_row2_col1" class="data row2 col1" >0.8304</td>
#       <td id="T_508a7_row2_col2" class="data row2 col2" >0.8209</td>
#       <td id="T_508a7_row2_col3" class="data row2 col3" >0.8304</td>
#       <td id="T_508a7_row2_col4" class="data row2 col4" >0.7698</td>
#       <td id="T_508a7_row2_col5" class="data row2 col5" >0.7816</td>
#       <td id="T_508a7_row2_col6" class="data row2 col6" >0.1775</td>
#       <td id="T_508a7_row2_col7" class="data row2 col7" >0.2290</td>
#       <td id="T_508a7_row2_col8" class="data row2 col8" >1.7200</td>
#     </tr>
#     <tr>
#       <th id="T_508a7_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_508a7_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_508a7_row3_col1" class="data row3 col1" >0.8275</td>
#       <td id="T_508a7_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_508a7_row3_col3" class="data row3 col3" >0.8275</td>
#       <td id="T_508a7_row3_col4" class="data row3 col4" >0.7564</td>
#       <td id="T_508a7_row3_col5" class="data row3 col5" >0.7623</td>
#       <td id="T_508a7_row3_col6" class="data row3 col6" >0.0726</td>
#       <td id="T_508a7_row3_col7" class="data row3 col7" >0.1328</td>
#       <td id="T_508a7_row3_col8" class="data row3 col8" >0.1790</td>
#     </tr>
#     <tr>
#       <th id="T_508a7_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_508a7_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_508a7_row4_col1" class="data row4 col1" >0.8272</td>
#       <td id="T_508a7_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_508a7_row4_col3" class="data row4 col3" >0.8272</td>
#       <td id="T_508a7_row4_col4" class="data row4 col4" >0.6843</td>
#       <td id="T_508a7_row4_col5" class="data row4 col5" >0.7490</td>
#       <td id="T_508a7_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_508a7_row4_col7" class="data row4 col7" >0.0000</td>
#       <td id="T_508a7_row4_col8" class="data row4 col8" >0.0170</td>
#     </tr>
#     <tr>
#       <th id="T_508a7_level0_row5" class="row_heading level0 row5" >dummy</th>
#       <td id="T_508a7_row5_col0" class="data row5 col0" >Dummy Classifier</td>
#       <td id="T_508a7_row5_col1" class="data row5 col1" >0.8272</td>
#       <td id="T_508a7_row5_col2" class="data row5 col2" >0.5000</td>
#       <td id="T_508a7_row5_col3" class="data row5 col3" >0.8272</td>
#       <td id="T_508a7_row5_col4" class="data row5 col4" >0.6843</td>
#       <td id="T_508a7_row5_

# %%
lgbm = create_model('lightgbm', class_weight='balanced')
# Out:
# <style type="text/css">
# #T_a3b0a_row10_col0, #T_a3b0a_row10_col1, #T_a3b0a_row10_col2, #T_a3b0a_row10_col3, #T_a3b0a_row10_col4, #T_a3b0a_row10_col5, #T_a3b0a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a3b0a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3b0a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a3b0a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a3b0a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a3b0a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a3b0a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a3b0a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a3b0a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3b0a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a
td>
#     </tr>
#     <tr>
#       <th id="T_a3b0a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a3b0a_row7_col0" class="data row7 col0" >0.7256</td>
#       <td id="T_a3b0a_row7_col1" class="data row7 col1" >0.8144</td>
#       <td id="T_a3b0a_row7_col2" class="data row7 col2" >0.7256</td>
#       <td id="T_a3b0a_row7_col3" class="data row7 col3" >0.7916</td>
#       <td id="T_a3b0a_row7_col4" class="data row7 col4" >0.7533</td>
#       <td id="T_a3b0a_row7_col5" class="data row7 col5" >0.2658</td>
#       <td id="T_a3b0a_row7_col6" class="data row7 col6" >0.2755</td>
#     </tr>
#     <tr>
#       <th id="T_a3b0a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a3b0a_row8_col0" class="data row8 col0" >0.7362</td>
#       <td id="T_a3b0a_row8_col1" class="data row8 col1" >0.7985</td>
#       <td id="T_a3b0a_row8_col2" class="data row8 col2" >0.7362</td>
#       <td id="T_a3b0a_row8_col3" class="data row8 col3" >0.7899</td>
#       <td id="T_a3b0a_row8_col4" class="data row8 col4" >0.7596</td>
#       <td id="T_a3b0a_row8_col5" class="data row8 col5" >0.2638</td>
#       <td id="T_a3b0a_row8_col6" class="data row8 col6" >0.2704</td>
#     </tr>
#     <tr>
#       <th id="T_a3b0a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a3b0a_row9_col0" class="data row9 col0" >0.7773</td>
#       <td id="T_a3b0a_row9_col1" class="data row9 col1" >0.8012</td>
#       <td id="T_a3b0a_row9_col2" class="data row9 col2" >0.7773</td>
#       <td id="T_a3b0a_row9_col3" class="data row9 col3" >0.8028</td>
#       <td id="T_a3b0a_row9_col4" class="data row9 col4" >0.7883</td>
#       <td id="T_a3b0a_row9_col5" class="data row9 col5" >0.3307</td>
#       <td id="T_a3b0a_row9_col6" class="data row9 col6" >0.3338</td>
#     </tr>
#     <tr>
#       <th id="T_a3b0a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a3b0a_row10_col0" class="data row10 col0" >0.7472</td>
#       <td id="T_a3b0a_row10_col1" class="data row10 col1" >0.8141</td>
#       <td id="T_a3b0a_row10_col2" class="data row10 col2" >0.7472</td>
#       <td id="T_a3b0a_row10_col3" class="data row10 col3" >0.7965</td>
#       <td id="T_a3b0a_row10_col4" class="data row10 col4" >0.7684</td>
#       <td id="T_a3b0a_row10_col5" class="data row10 col5" >0.2903</td>
#       <td id="T_a3b0a_row10_col6" class="data row10 col6" >0.2969</td>
#     </tr>
#     <tr>
#       <th id="T_a3b0a_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_a3b0a_row11_col0" class="data row11 col0" >0.0229</td>
#       <td id="T_a3b0a_row11_col1" class="data row11 col1" >0.0163</td>
#       <td id="T_a3b0a_row11_col2" class="data row11 col2" >0.0229</td>
#       <td id="T_a3b0a_row11_col3" class="data row11 col3" >0.0126</td>
#       <td id="T_a3b0a_row11_col4

# %%
tuned_lgbm = tune_model(lgbm, optimize='F1')
# Out:
# <style type="text/css">
# #T_5ce25_row10_col0, #T_5ce25_row10_col1, #T_5ce25_row10_col2, #T_5ce25_row10_col3, #T_5ce25_row10_col4, #T_5ce25_row10_col5, #T_5ce25_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5ce25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ce25_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5ce25_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5ce25_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5ce25_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5ce25_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5ce25_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5ce25_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ce25_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ce25_row0_col0" class="data row0 col0" >0.7729</td>
#       <td id="T_5ce25_row0_col1" class="data row0 col1" >0.8200</td>
#       <td id="T_5ce25_row0_col2" class="data row0 col2" >0.7729</td>
#       <td id="T_5ce25_row0_col3" class="data row0 col3" >0.7856</td>
#       <td id="T_5ce25_row0_col4" class="data row0 col4" >0.7790</td>
#       <td id="T_5ce25_row0_col5" class="data row0 col5" >0.2753</td>
#       <td id="T_5ce25_row0_col6" class="data row0 col6" >0.2758</td>
#     </tr>
#     <tr>
#       <th id="T_5ce25_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5
td>
#     </tr>
#     <tr>
#       <th id="T_5ce25_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5ce25_row7_col0" class="data row7 col0" >0.7555</td>
#       <td id="T_5ce25_row7_col1" class="data row7 col1" >0.7775</td>
#       <td id="T_5ce25_row7_col2" class="data row7 col2" >0.7555</td>
#       <td id="T_5ce25_row7_col3" class="data row7 col3" >0.7680</td>
#       <td id="T_5ce25_row7_col4" class="data row7 col4" >0.7616</td>
#       <td id="T_5ce25_row7_col5" class="data row7 col5" >0.2255</td>
#       <td id="T_5ce25_row7_col6" class="data row7 col6" >0.2259</td>
#     </tr>
#     <tr>
#       <th id="T_5ce25_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5ce25_row8_col0" class="data row8 col0" >0.7630</td>
#       <td id="T_5ce25_row8_col1" class="data row8 col1" >0.7577</td>
#       <td id="T_5ce25_row8_col2" class="data row8 col2" >0.7630</td>
#       <td id="T_5ce25_row8_col3" class="data row8 col3" >0.7796</td>
#       <td id="T_5ce25_row8_col4" class="data row8 col4" >0.7709</td>
#       <td id="T_5ce25_row8_col5" class="data row8 col5" >0.2587</td>
#       <td id="T_5ce25_row8_col6" class="data row8 col6" >0.2597</td>
#     </tr>
#     <tr>
#       <th id="T_5ce25_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5ce25_row9_col0" class="data row9 col0" >0.7883</td>
#       <td id="T_5ce25_row9_col1" class="data row9 col1" >0.7635</td>
#       <td id="T_5ce25_row9_col2" class="data row9 col2" >0.7883</td>
#       <td id="T_5ce25_row9_col3" class="data row9 col3" >0.7759</td>
#       <td id="T_5ce25_row9_col4" class="data row9 col4" >0.7818</td>
#       <td id="T_5ce25_row9_col5" class="data row9 col5" >0.2595</td>
#       <td id="T_5ce25_row9_col6" class="data row9 col6" >0.2601</td>
#     </tr>
#     <tr>
#       <th id="T_5ce25_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_5ce25_row10_col0" class="data row10 col0" >0.7681</td>
#       <td id="T_5ce25_row10_col1" class="data row10 col1" >0.7845</td>
#       <td id="T_5ce25_row10_col2" class="data row10 col2" >0.7681</td>
#       <td id="T_5ce25_row10_col3" class="data row10 col3" >0.7749</td>
#       <td id="T_5ce25_row10_col4" class="data row10 col4" >0.7713</td>
#       <td id="T_5ce25_row10_col5" class="data row10 col5" >0.2477</td>
#       <td id="T_5ce25_row10_col6" class="data row10 col6" >0.2481</td>
#     </tr>
#     <tr>
#       <th id="T_5ce25_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_5ce25_row11_col0" class="data row11 col0" >0.0124</td>
#       <td id="T_5ce25_row11_col1" class="data row11 col1" >0.0167</td>
#       <td id="T_5ce25_row11_col2" class="data row11 col2" >0.0124</td>
#       <td id="T_5ce25_row11_col3" class="data row11 col3" >0.0081</td>
#       <td id="T_5ce25_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
final_model = finalize_model(tuned_lgbm)
prediction = predict_model(final_model, data = X_test)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1

# %%
from sklearn.metrics import f1_score
f1 = f1_score(y_test, prediction['prediction_label'], average ="weighted")
print(f"f1_score: {f1:.4f}")
# Out:
# f1_score: 0.6913

# %%
# 혼동 행렬 계산
cm = confusion_matrix(y_test, prediction['prediction_label'])

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Class 0', 'Class 1', 'Class 2'], yticklabels=['Class 0', 'Class 1', 'Class 2'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
model_feature_importance = final_model.feature_importances_

# 중요도 값과 feature 이름을 함께 출력
features = get_config('X_train').columns
importance_df = pd.DataFrame({'Feature': features, 'Importance': model_feature_importance})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=importance_df)
plt.title('Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %%
X_test_transformed = final_model[:-1].transform(X_test)

explainer = shap.Explainer(final_model.steps[-1][1])
shap_values = explainer(X_test_transformed)

for class_idx in range(shap_values.values.shape[2]):
    print(f"클래스 {class_idx}")
    plt.figure(figsize=(8, 4))
    shap.summary_plot(shap_values.values[:, :, class_idx], X_test_transformed)
# Out:
# 클래스 0
# 클래스 1
# 클래스 2
