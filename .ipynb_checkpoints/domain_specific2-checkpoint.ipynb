# %% [markdown]
# # 특화 모델2(중구)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pycaret.classification import *
from sklearn.utils import resample
import shap

# %%
df = pd.read_csv("seoul_preprocessed.csv")
print(df.shape)
# Out:
# (44090, 31)

# %%
test_df = df.sample(frac=0.2, random_state=42)
train_df = df.drop(index=test_df.index)

# %%
# test를 제외한 데이터로 risk level 추출
df_nonzero = train_df[train_df['tow_count'] > 0]

# `tow_count` 값으로 정렬
df_nonzero = df_nonzero.sort_values(by='tow_count')

total_nonzero = len(df_nonzero)

mid_end = int(total_nonzero*1/2) # 절반

# 각 구간 끝값 (경계)
mid_end_value = df_nonzero.iloc[mid_end - 1]['tow_count']  # 가운데 구간 끝값

print(f"가운데 구간 끝값: {mid_end_value}\n")


train_df['risk_level'] = train_df['tow_count'].apply(
    lambda x: 0 if x == 0 else (1 if x <= mid_end_value else 2)
)

test_df['risk_level'] = test_df['tow_count'].apply(
    lambda x: 0 if x == 0 else (1 if x <= mid_end_value else 2)
)


# 결과 확인
print(train_df[['tow_count', 'risk_level']].tail())
# Out:
# 가운데 구간 끝값: 2
#
#        tow_count  risk_level
# 44085          0           0
# 44086          0           0
# 44087          0           0
# 44088          0           0
# 44089          0           0

# %%
# 지역 기반 분할
selected_gu = ["중구"]
train_df = train_df[train_df["SIG_KOR_NM"].isin(selected_gu)]

# %%
features = train_df.columns[3:-2]
target = 'risk_level'
del train_df['tow_count']
del test_df['tow_count']

# 테스트 데이터 준비
train = train_df.iloc[:,3:]
X_test, y_test   = test_df[features], test_df[target]

# %%
exp_clf = setup(data = train, target = target, session_id=42)
# Out:
# <style type="text/css">
# #T_32f8f_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_32f8f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32f8f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_32f8f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32f8f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_32f8f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_32f8f_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_32f8f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_32f8f_row1_col1" class="data row1 col1" >risk_level</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_32f8f_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_32f8f_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_32f8f_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_32f8f_row3_col1" class="data row3 col1" >(773, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_32f8f_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_32f8f_row4_col1" class="data row4 col1" >(773, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_32f8f_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_32f8f_row5_col1" class="data row5 col1" >(541, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_32f8f_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_32f8f_row6_col1" class="data row6 col1" >(232, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_32f8f_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_32f8f_row7_col1" class="data row7 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_32f8f_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_32f8f_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_32f8f_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_32f8f_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_32f8f_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_32f8f_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_32f8f_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_32f8f_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_32f8f_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_32f8f_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_32f8f_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_32f8f_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_32f8f_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_32f8f_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_32f8f_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_32f8f_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_32f8f_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_32f8f_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_32f8f_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_32f8f_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_32f8f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_32f8f_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_32f8f_row18_col1" class="data row18 col1" >5484</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_06bde th {
#   text-align: left;
# }
# #T_06bde_row0_col0, #T_06bde_row0_col2, #T_06bde_row0_col4, #T_06bde_row0_col5, #T_06bde_row0_col6, #T_06bde_row0_col7, #T_06bde_row1_col0, #T_06bde_row1_col1, #T_06bde_row1_col2, #T_06bde_row1_col3, #T_06bde_row1_col4, #T_06bde_row1_col5, #T_06bde_row1_col6, #T_06bde_row1_col7, #T_06bde_row2_col0, #T_06bde_row2_col1, #T_06bde_row2_col2, #T_06bde_row2_col3, #T_06bde_row2_col4, #T_06bde_row2_col5, #T_06bde_row2_col6, #T_06bde_row2_col7, #T_06bde_row3_col0, #T_06bde_row3_col1, #T_06bde_row3_col2, #T_06bde_row3_col3, #T_06bde_row4_col0, #T_06bde_row4_col1, #T_06bde_row4_col2, #T_06bde_row4_col3, #T_06bde_row4_col4, #T_06bde_row4_col5, #T_06bde_row4_col6, #T_06bde_row4_col7, #T_06bde_row5_col0, #T_06bde_row5_col1, #T_06bde_row5_col3, #T_06bde_row5_col4, #T_06bde_row5_col5, #T_06bde_row5_col6, #T_06bde_row5_col7, #T_06bde_row6_col0, #T_06bde_row6_col1, #T_06bde_row6_col2, #T_06bde_row6_col3, #T_06bde_row6_col4, #T_06bde_row6_col5, #T_06bde_row6_col6, #T_06bde_row6_col7, #T_06bde_row7_col0, #T_06bde_row7_col1, #T_06bde_row7_col2, #T_06bde_row7_col3, #T_06bde_row7_col4, #T_06bde_row7_col5, #T_06bde_row7_col6, #T_06bde_row7_col7, #T_06bde_row8_col0, #T_06bde_row8_col1, #T_06bde_row8_col2, #T_06bde_row8_col3, #T_06bde_row8_col4, #T_06bde_row8_col5, #T_06bde_row8_col6, #T_06bde_row8_col7, #T_06bde_row9_col0, #T_06bde_row9_col1, #T_06bde_row9_col2, #T_06bde_row9_col3, #T_06bde_row9_col4, #T_06bde_row9_col5, #T_06bde_row9_col6, #T_06bde_row9_col7, #T_06bde_row10_col0, #T_06bde_row10_col1, #T_06bde_row10_col2, #T_06bde_row10_col3, #T_06bde_row10_col4, #T_06bde_row10_col5, #T_06bde_row10_col6, #T_06bde_row10_col7, #T_06bde_row11_col0, #T_06bde_row11_col1, #T_06bde_row11_col2, #T_06bde_row11_col3, #T_06bde_row11_col4, #T_06bde_row11_col5, #T_06bde_row11_col6, #T_06bde_row11_col7, #T_06bde_row12_col0, #T_06bde_row12_col1, #T_06bde_row12_col2, #T_06bde_row12_col3, #T_06bde_row12_col4, #T_06bde_row12_col5, #T_06bde_row12_col6, #T_06bde_row12_col7, #T_06bde_row13_col0, #T_06bde_row13_col1, #T_06bde_row13_col2, #T_06bde_row13_col3, #T_06bde_row13_col4, #T_06bde_row13_col5, #T_06bde_row13_col6, #T_06bde_row13_col7, #T_06bde_row14_col0, #T_06bde_row14_col1, #T_06bde_row14_col2, #T_06bde_row14_col3, #T_06bde_row14_col4, #T_06bde_row14_col5, #T_06bde_row14_col6, #T_06bde_row14_col7 {
#   text-align: left;
# }
# #T_06bde_row0_col1, #T_06bde_row0_col3, #T_06bde_row3_col4, #T_06bde_row3_col5, #T_06bde_row3_col6, #T_06bde_row3_col7, #T_06bde_row5_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_06bde_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_06bde_row1_col8, #T_06bde_row2_col8, #T_06bde_row3_col8, #T_06bde_row4_col8, #T_06bde_row5_col8, #T_06bde_row6_col8, #T_06bde_row7_col8, #T_06bde_row8_col8, #T_06bde_row9_col8, #T_06bde_row10_col8, #T_06bde_row11_col8, #T_06bde_row12_col8, #T_06bde_row13_col8, #T_06bde_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_06bde">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06bde_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_06bde_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_06bde_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_06bde_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_06bde_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_06bde_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_06bde_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_06bde_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_06bde_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06bde_level0_row0" class="row_heading level0 row0" >dummy</th>
#       <td id="T_06bde_row0_col0" class="data row0 col0" >Dummy Classifier</td>
#       <td id="T_06bde_row0_col1" class="data row0 col1" >0.7560</td>
#       <td id="T_06bde_row0_col2" class="data row0 col2" >0.5000</td>
#       <td id="T
td>
#     </tr>
#     <tr>
#       <th id="T_fb9c9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fb9c9_row7_col0" class="data row7 col0" >0.7222</td>
#       <td id="T_fb9c9_row7_col1" class="data row7 col1" >0.7126</td>
#       <td id="T_fb9c9_row7_col2" class="data row7 col2" >0.7222</td>
#       <td id="T_fb9c9_row7_col3" class="data row7 col3" >0.6568</td>
#       <td id="T_fb9c9_row7_col4" class="data row7 col4" >0.6861</td>
#       <td id="T_fb9c9_row7_col5" class="data row7 col5" >0.1692</td>
#       <td id="T_fb9c9_row7_col6" class="data row7 col6" >0.1761</td>
#     </tr>
#     <tr>
#       <th id="T_fb9c9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fb9c9_row8_col0" class="data row8 col0" >0.8148</td>
#       <td id="T_fb9c9_row8_col1" class="data row8 col1" >0.8564</td>
#       <td id="T_fb9c9_row8_col2" class="data row8 col2" >0.8148</td>
#       <td id="T_fb9c9_row8_col3" class="data row8 col3" >0.8218</td>
#       <td id="T_fb9c9_row8_col4" class="data row8 col4" >0.8073</td>
#       <td id="T_fb9c9_row8_col5" class="data row8 col5" >0.5028</td>
#       <td id="T_fb9c9_row8_col6" class="data row8 col6" >0.5095</td>
#     </tr>
#     <tr>
#       <th id="T_fb9c9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fb9c9_row9_col0" class="data row9 col0" >0.7037</td>
#       <td id="T_fb9c9_row9_col1" class="data row9 col1" >0.6625</td>
#       <td id="T_fb9c9_row9_col2" class="data row9 col2" >0.7037</td>
#       <td id="T_fb9c9_row9_col3" class="data row9 col3" >0.6291</td>
#       <td id="T_fb9c9_row9_col4" class="data row9 col4" >0.6625</td>
#       <td id="T_fb9c9_row9_col5" class="data row9 col5" >0.1496</td>
#       <td id="T_fb9c9_row9_col6" class="data row9 col6" >0.1581</td>
#     </tr>
#     <tr>
#       <th id="T_fb9c9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_fb9c9_row10_col0" class="data row10 col0" >0.7281</td>
#       <td id="T_fb9c9_row10_col1" class="data row10 col1" >0.6685</td>
#       <td id="T_fb9c9_row10_col2" class="data row10 col2" >0.7281</td>
#       <td id="T_fb9c9_row10_col3" class="data row10 col3" >0.6838</td>
#       <td id="T_fb9c9_row10_col4" class="data row10 col4" >0.6924</td>
#       <td id="T_fb9c9_row10_col5" class="data row10 col5" >0.1757</td>
#       <td id="T_fb9c9_row10_col6" class="data row10 col6" >0.1940</td>
#     </tr>
#     <tr>
#       <th id="T_fb9c9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_fb9c9_row11_col0" class="data row11 col0" >0.0516</td>
#       <td id="T_fb9c9_row11_col1" class="data row11 col1" >0.0879</td>
#       <td id="T_fb9c9_row11_col2" class="data row11 col2" >0.0516</td>
#       <td id="T_fb9c9_row11_col3" class="data row11 col3" >0.0817</td>
#       <td id="T_fb9c9_row11_co

# %%
tuned_lgbm = tune_model(lgbm, optimize='F1')
# Out:
# <style type="text/css">
# #T_331a4_row10_col0, #T_331a4_row10_col1, #T_331a4_row10_col2, #T_331a4_row10_col3, #T_331a4_row10_col4, #T_331a4_row10_col5, #T_331a4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_331a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_331a4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_331a4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_331a4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_331a4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_331a4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_331a4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_331a4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_331a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_331a4_row0_col0" class="data row0 col0" >0.6545</td>
#       <td id="T_331a4_row0_col1" class="data row0 col1" >0.5610</td>
#       <td id="T_331a4_row0_col2" class="data row0 col2" >0.6545</td>
#       <td id="T_331a4_row0_col3" class="data row0 col3" >0.6327</td>
#       <td id="T_331a4_row0_col4" class="data row0 col4" >0.6429</td>
#       <td id="T_331a4_row0_col5" class="data row0 col5" >0.1129</td>
#       <td id="T_331a4_row0_col6" class="data row0 col6" >0.1135</td>
#     </tr>
#     <tr>
#       <th id="T_331a4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T
td>
#     </tr>
#     <tr>
#       <th id="T_331a4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_331a4_row8_col0" class="data row8 col0" >0.6852</td>
#       <td id="T_331a4_row8_col1" class="data row8 col1" >0.8089</td>
#       <td id="T_331a4_row8_col2" class="data row8 col2" >0.6852</td>
#       <td id="T_331a4_row8_col3" class="data row8 col3" >0.6943</td>
#       <td id="T_331a4_row8_col4" class="data row8 col4" >0.6895</td>
#       <td id="T_331a4_row8_col5" class="data row8 col5" >0.2214</td>
#       <td id="T_331a4_row8_col6" class="data row8 col6" >0.2216</td>
#     </tr>
#     <tr>
#       <th id="T_331a4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_331a4_row9_col0" class="data row9 col0" >0.6481</td>
#       <td id="T_331a4_row9_col1" class="data row9 col1" >0.7096</td>
#       <td id="T_331a4_row9_col2" class="data row9 col2" >0.6481</td>
#       <td id="T_331a4_row9_col3" class="data row9 col3" >0.6448</td>
#       <td id="T_331a4_row9_col4" class="data row9 col4" >0.6445</td>
#       <td id="T_331a4_row9_col5" class="data row9 col5" >0.1739</td>
#       <td id="T_331a4_row9_col6" class="data row9 col6" >0.1758</td>
#     </tr>
#     <tr>
#       <th id="T_331a4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_331a4_row10_col0" class="data row10 col0" >0.6562</td>
#       <td id="T_331a4_row10_col1" class="data row10 col1" >0.6597</td>
#       <td id="T_331a4_row10_col2" class="data row10 col2" >0.6562</td>
#       <td id="T_331a4_row10_col3" class="data row10 col3" >0.6597</td>
#       <td id="T_331a4_row10_col4" class="data row10 col4" >0.6557</td>
#       <td id="T_331a4_row10_col5" class="data row10 col5" >0.1403</td>
#       <td id="T_331a4_row10_col6" class="data row10 col6" >0.1417</td>
#     </tr>
#     <tr>
#       <th id="T_331a4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_331a4_row11_col0" class="data row11 col0" >0.0423</td>
#       <td id="T_331a4_row11_col1" class="data row11 col1" >0.0918</td>
#       <td id="T_331a4_row11_col2" class="data row11 col2" >0.0423</td>
#       <td id="T_331a4_row11_col3" class="data row11 col3" >0.0384</td>
#       <td id="T_331a4_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
final_model = finalize_model(tuned_lgbm)
prediction = predict_model(final_model, data = X_test)

# %%
prediction
# Out:
#        isSchool  rental_count  return_count     apart  closest_hospital_dist  \
# 38207         0      0.000000      0.000000  0.000000               5.325478
# 34015         0      0.000000      0.000000  0.000000               5.086802
# 20315         0      3.559028      3.605673  0.000000               3.972599
# 32199         0      0.000000      0.000000  0.000000               4.434495
# 29840         0      0.000000      0.000000  7.850103               4.027646
# ...         ...           ...           ...       ...                    ...
# 41569         0      0.000000      0.000000  0.000000               4.783676
# 22776         0      0.000000      0.000000  0.000000               3.764289
# 26942         0      0.000000      0.000000  7.126891               5.059654
# 31596         0      4.559633      4.548770  5.891644               2.166850
# 22167         0      0.000000      0.000000  0.000000               5.406640
#
#        closest_convenience_dist  closest_culture_dist   age_20s   age_30s  \
# 38207                  4.627883              6.015660  8.276779  8.681676
# 34015                  3.935616              5.987284  8.486584  8.766016
# 20315                  3.193857              5.530240  7.868601  7.641568
# 32199                  4.113351              6.348045  8.328084  8.386347
# 29840                  4.496809              6.367069  7.717233  8.243472
# ...                         ...                   ...       ...       ...
# 41569                  4.556271              6.712779  7.117584  7.240508
# 22776                  3.869840              5.768969  7.857319  7.983320
# 26942                  4.032720              6.501971  8.422400  8.412317
# 31596                  2.288287              5.934356  8.995362  8.950693
# 22167                  3.831243              3.894558  8.902174  8.228725
#
#         age_40s  ...  subway_avg_alight     area20     area30     area40  \
# 38207  8.432479  ...                0.0  11.440591  11.843297  11.651719
# 34015  8.777035  ...                0.0  12.414078  12.633709  12.621968
# 20315  7.488942  ...                0.0  12.223945  12.231263  12.244367
# 32199  8.454794  ...                0.0  12.411438  12.528260  12.538799
# 29840  8.305729  ...                0.0   0.000000   0.000000   0.000000
# ...         ...  ...                ...        ...        ...        ...
# 41569  7.263411  ...                0.0   0.000000   0.000000   0.000000
# 22776  8.158035  ...                0.0   9.822779  10.120211  10.381793
# 26942  8.552222  ...                0.0   0.000000   0.000000   0.000000
# 31596  8.692975  ...                0.0  12.733198  12.722761  12.550138
# 22167  8.120695  ...                0.0  12.870352  12.086361  11.915773
#
#        wp_area20  wp_area30  wp_area40  isCommercial  prediction_label  \
# 38207   3.795489   4.430817   4.471639             1                 0
# 34015   6.658653   6.378850   6.437352             1                 0
# 20315   3.481240   3.778491   3.921973             1                 1
# 32199   4.200954   4.943427   5.154736             1                 0
# 29840   0.000000   0.000000   0.000000             0                 0
# ...          ...        ...        ...           ...               ...
# 41569   0.000000   0.000000   0.000000             1                 0
# 22776   2.505526   2.602690   2.740840             1                 0
# 26942   0.000000   0.000000   0.000000             1                 0
# 31596   7.326795   7.761639   7.744245             1                 0
# 22167   3.341094   3.917011   3.970292             1                 0
#
#        prediction_score
# 38207            0.9941
# 34015            0.9887
# 20315            0.6100
# 32199            0.9729
# 29840            0.9242
# ...                 ...
# 41569            0.6999
# 22776            0.9843
# 26942            0.9898
# 31596            0.9557
# 22167            0.9890
#
# [8818 rows x 29 columns]

# %%
from sklearn.metrics import f1_score
f1 = f1_score(y_test, prediction['prediction_label'], average ="weighted")
print(f"f1_score: {f1:.4f}")
# Out:
# f1_score: 0.7106

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 혼동 행렬 계산
cm = confusion_matrix(y_test, prediction['prediction_label'])

# 혼동 행렬 시각화
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Class 0', 'Class 1', 'Class 2', 'Class 3'], yticklabels=['Class 0', 'Class 1', 'Class 2', 'Class 3'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
model_feature_importance = final_model.feature_importances_

# 중요도 값과 feature 이름을 함께 출력
features = get_config('X_train').columns
importance_df = pd.DataFrame({'Feature': features, 'Importance': model_feature_importance})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=importance_df)
plt.title('Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %%
X_test_transformed = final_model[:-1].transform(X_test)

explainer = shap.Explainer(final_model.steps[-1][1])
shap_values = explainer(X_test_transformed)

for class_idx in range(shap_values.values.shape[2]):
    print(f"클래스 {class_idx}")
    plt.figure(figsize=(8, 4))
    shap.summary_plot(shap_values.values[:, :, class_idx], X_test_transformed)
# Out:
# 클래스 0
# 클래스 1
# 클래스 2

# %%
# 모델 저장
save_model(final_model, 'domain_specific_model_2')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['isSchool', 'rental_count',
#                                               'return_count', 'apart',
#                                               'closest_hospital_dist',
#                                               'closest_convenience_dist',
#                                               'closest_culture_dist', 'age_20s',
#                                               'age_30s', 'age_40s',
#                                               'crosswalk_count',
#                                               'closest_cross_dist', 'bus_count',
#                                               'closest_bus_dist', 'subway_count',
#                                               'clos...
#                   LGBMClassifier(boosting_type='gbdt', class_weight='balanced',
#                                  colsample_bytree=1.0, importance_type='split',
#                                  learning_rate=0.1, max_depth=-1,
#                                  min_child_samples=20, min_child_weight=0.001,
#                                  min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                  num_leaves=31, objective=None, random_state=42,
#                                  reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                                  subsample_for_bin=200000, subsample_freq=0))],
#           verbose=False),
#  'domain_specific_model_2.pkl')
