# %% [markdown]
# # 특화 모델3(강동구, 관악구, 광진구, 구로구, 금천구, 노원구, 동대문구, 동작구, 서대문구, 송파구, 은평구)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pycaret.classification import *
from sklearn.utils import resample
import shap

# %%
df = pd.read_csv("data/seoul_preprocessed.csv")
print(df.shape)
# Out:
# (44090, 31)

# %%
test_df = df.sample(frac=0.2, random_state=42)
train_df = df.drop(index=test_df.index)

# %%
# test를 제외한 데이터로 risk level 추출
df_nonzero = train_df[train_df['tow_count'] > 0]

# `tow_count` 값으로 정렬
df_nonzero = df_nonzero.sort_values(by='tow_count')

total_nonzero = len(df_nonzero)

mid_end = int(total_nonzero*1/2) # 절반

# 각 구간 끝값 (경계)
mid_end_value = df_nonzero.iloc[mid_end - 1]['tow_count']  # 가운데 구간 끝값

print(f"가운데 구간 끝값: {mid_end_value}\n")


train_df['risk_level'] = train_df['tow_count'].apply(
    lambda x: 0 if x == 0 else (1 if x <= mid_end_value else 2)
)

test_df['risk_level'] = test_df['tow_count'].apply(
    lambda x: 0 if x == 0 else (1 if x <= mid_end_value else 2)
)


# 결과 확인
print(train_df[['tow_count', 'risk_level']].tail())
# Out:
# 가운데 구간 끝값: 2
#
#        tow_count  risk_level
# 44085          0           0
# 44086          0           0
# 44087          0           0
# 44088          0           0
# 44089          0           0

# %%
# 지역 기반 분할
selected_gu = ["강동구", "관악구", "광진구", "구로구", "금천구", "노원구", "동대문구", "동작구", "서대문구", "송파구", "은평구"]
train_df = train_df[train_df["SIG_KOR_NM"].isin(selected_gu)]

# %%
features = train_df.columns[3:-2]
target = 'risk_level'
del train_df['tow_count']
del test_df['tow_count']

# 테스트 데이터 준비
train = train_df.iloc[:,3:]
X_test, y_test   = test_df[features], test_df[target]

# %%
exp_clf = setup(data = train, target = target, session_id=42)
# Out:
# <style type="text/css">
# #T_d6cfc_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d6cfc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6cfc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d6cfc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6cfc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6cfc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d6cfc_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d6cfc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d6cfc_row1_col1" class="data row1 col1" >risk_level</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d6cfc_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d6cfc_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d6cfc_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d6cfc_row3_col1" class="data row3 col1" >(14978, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d6cfc_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d6cfc_row4_col1" class="data row4 col1" >(14978, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d6cfc_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d6cfc_row5_col1" class="data row5 col1" >(10484, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d6cfc_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d6cfc_row6_col1" class="data row6 col1" >(4494, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d6cfc_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_d6cfc_row7_col1" class="data row7 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d6cfc_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_d6cfc_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d6cfc_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_d6cfc_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d6cfc_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_d6cfc_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d6cfc_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_d6cfc_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d6cfc_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_d6cfc_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d6cfc_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_d6cfc_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d6cfc_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_d6cfc_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d6cfc_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_d6cfc_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d6cfc_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_d6cfc_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d6cfc_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_d6cfc_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d6cfc_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d6cfc_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_d6cfc_row18_col1" class="data row18 col1" >3cd6</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_6acc3 th {
#   text-align: left;
# }
# #T_6acc3_row0_col0, #T_6acc3_row0_col2, #T_6acc3_row0_col4, #T_6acc3_row0_col5, #T_6acc3_row0_col6, #T_6acc3_row0_col7, #T_6acc3_row1_col0, #T_6acc3_row1_col1, #T_6acc3_row1_col3, #T_6acc3_row1_col4, #T_6acc3_row1_col6, #T_6acc3_row2_col0, #T_6acc3_row2_col1, #T_6acc3_row2_col2, #T_6acc3_row2_col3, #T_6acc3_row2_col4, #T_6acc3_row2_col5, #T_6acc3_row2_col6, #T_6acc3_row2_col7, #T_6acc3_row3_col0, #T_6acc3_row3_col1, #T_6acc3_row3_col2, #T_6acc3_row3_col3, #T_6acc3_row3_col4, #T_6acc3_row3_col5, #T_6acc3_row3_col6, #T_6acc3_row3_col7, #T_6acc3_row4_col0, #T_6acc3_row4_col1, #T_6acc3_row4_col2, #T_6acc3_row4_col3, #T_6acc3_row4_col4, #T_6acc3_row4_col5, #T_6acc3_row4_col6, #T_6acc3_row4_col7, #T_6acc3_row5_col0, #T_6acc3_row5_col1, #T_6acc3_row5_col2, #T_6acc3_row5_col3, #T_6acc3_row5_col4, #T_6acc3_row5_col5, #T_6acc3_row5_col6, #T_6acc3_row5_col7, #T_6acc3_row6_col0, #T_6acc3_row6_col1, #T_6acc3_row6_col2, #T_6acc3_row6_col3, #T_6acc3_row6_col4, #T_6acc3_row6_col5, #T_6acc3_row6_col6, #T_6acc3_row6_col7, #T_6acc3_row7_col0, #T_6acc3_row7_col1, #T_6acc3_row7_col2, #T_6acc3_row7_col3, #T_6acc3_row7_col4, #T_6acc3_row7_col5, #T_6acc3_row7_col6, #T_6acc3_row7_col7, #T_6acc3_row8_col0, #T_6acc3_row8_col1, #T_6acc3_row8_col2, #T_6acc3_row8_col3, #T_6acc3_row8_col4, #T_6acc3_row8_col5, #T_6acc3_row8_col6, #T_6acc3_row8_col7, #T_6acc3_row9_col0, #T_6acc3_row9_col1, #T_6acc3_row9_col2, #T_6acc3_row9_col3, #T_6acc3_row9_col4, #T_6acc3_row9_col5, #T_6acc3_row9_col6, #T_6acc3_row9_col7, #T_6acc3_row10_col0, #T_6acc3_row10_col1, #T_6acc3_row10_col2, #T_6acc3_row10_col3, #T_6acc3_row10_col4, #T_6acc3_row10_col5, #T_6acc3_row10_col6, #T_6acc3_row10_col7, #T_6acc3_row11_col0, #T_6acc3_row11_col1, #T_6acc3_row11_col2, #T_6acc3_row11_col3, #T_6acc3_row11_col4, #T_6acc3_row11_col5, #T_6acc3_row11_col6, #T_6acc3_row11_col7, #T_6acc3_row12_col0, #T_6acc3_row12_col1, #T_6acc3_row12_col2, #T_6acc3_row12_col3, #T_6acc3_row12_col4, #T_6acc3_row12_col5, #T_6acc3_row12_col6, #T_6acc3_row12_col7, #T_6acc3_row13_col0, #T_6acc3_row13_col1, #T_6acc3_row13_col2, #T_6acc3_row13_col3, #T_6acc3_row13_col4, #T_6acc3_row13_col5, #T_6acc3_row13_col6, #T_6acc3_row13_col7, #T_6acc3_row14_col0, #T_6acc3_row14_col1, #T_6acc3_row14_col2, #T_6acc3_row14_col3, #T_6acc3_row14_col5, #T_6acc3_row14_col7 {
#   text-align: left;
# }
# #T_6acc3_row0_col1, #T_6acc3_row0_col3, #T_6acc3_row1_col2, #T_6acc3_row1_col5, #T_6acc3_row1_col7, #T_6acc3_row14_col4, #T_6acc3_row14_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6acc3_row0_col8, #T_6acc3_row1_col8, #T_6acc3_row2_col8, #T_6acc3_row3_col8, #T_6acc3_row4_col8, #T_6acc3_row5_col8, #T_6acc3_row6_col8, #T_6acc3_row8_col8, #T_6acc3_row9_col8, #T_6acc3_row10_col8, #T_6acc3_row11_col8, #T_6acc3_row12_col8, #T_6acc3_row13_col8, #T_6acc3_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6acc3_row7_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6acc3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6acc3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6acc3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6acc3_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_6acc3_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_6acc3_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_6acc3_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_6acc3_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_6acc3_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_6acc3_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6acc3_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_6acc3_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_6acc3_row0_col1" class="data row0 col1" >0.8089</td>
#       <td id="T_6acc3_row0_col2" class="data row0 col2" >0.7590</td>
#       <td id="T_6acc3_row0_col3" class="data row0 col3" >0.8089</td>
#       <td id="T_6acc3_row0_col4" class="data row0 col4" >0.7228</td>
#       <td id="T_6acc3_row0_col5" class="data row0 col5" >0.7354</td>
#       <td id="T_6acc3_row0_col6" class="data row0 col6" >0.0655</td>
#       <td id="T_6acc3_row0_col7" class="data row0 col7" >0.1232</td>
#       <td id="T_6acc3_row0_col8" class="data row0 col8" >1.0520</td>
#     </tr>
#     <tr>
#       <th id="T_6acc3_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_6acc3_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6acc3_row1_col1" class="data row1 col1" >0.8088</td>
#       <td id="T_6acc3_row1_col2" class="data row1 col2" >0.7843</td>
#       <td id="T_6acc3_row1_col3" class="data row1 col3" >0.8088</td>
#       <td id="T_6acc3_row1_col4" class="data row1 col4" >0.7343</td>
#       <td id="T_6acc3_row1_col5" class="data row1 col5" >0.7497</td>
#       <td id="T_6acc3_row1_col6" class="data row1 col6" >0.1347</td>
#       <td id="T_6acc3_row1_col7" class="data row1 col7" >0.1842</td>
#       <td id="T_6acc3_row1_col8" class="data row1 col8" >12.0040</td>
#     </tr>
#     <tr>
#       <th id="T_6acc3_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_6acc3_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_6acc3_row2_col1" class="data row2 col1" >0.8084</td>
#       <td id="T_6acc3_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_6acc3_row2_col3" class="data row2 col3" >0.8084</td>
#       <td id="T_6acc3_row2_col4" class="data row2 col4" >0.7313</td>
#       <td id="T_6acc3_row2_col5" class="data row2 col5" >0.7365</td>
#       <td id="T_6acc3_row2_col6" class="data row2 col6" >0.0708</td>
#       <td id="T_6acc3_row2_col7" class="data row2 col7" >0.1297</td>
#       <td id="T_6acc3_row2_col8" class="data row2 col8" >7.4540</td>
#     </tr>
#     <tr>
#       <th id="T_6acc3_level0_row3" class="row_heading level0 row3" >dummy</th>
#       <td id="T_6acc3_row3_col0" class="data row3 col0" >Dummy Classifier</td>
#       <td id="T_6acc3_row3_col1" class="data row3 col1" >0.8078</td>
#       <td id="T_6acc3_row3_col2" class="data row3 col2" >0.5000</td>
#       <td id="T_6acc3_row3_col3" class="data row3 col3" >0.8078</td>
#       <td id="T_6acc3_row3_col4" class="data row3 col4" >0.6525</td>
#       <td id="T_6acc3_row3_col5" class="data row3 col5" >0.7219</td>
#       <td id="T_6acc3_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_6acc3_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_6acc3_row3_col8" class="data row3 col8" >0.0840</td>
#     </tr>
#     <tr>
#       <th id="T_6acc3_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_6acc3_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_6acc3_row4_col1" class="data row4 col1" >0.8076</td>
#       <td id="T_6acc3_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_6acc3_row4_col3" class="data row4 col3" >0.8076</td>
#       <td id="T_6acc3_row4_col4" class="data row4 col4" >0.6679</td>
#       <td id="T_6acc3_row4_col5" class="data row4 col5" >0.7224</td>
#       <td id="T_6acc3_row4_col6" class="data row4 col6" >0.0023</td>
#       <td id="T_6acc3_row4_col7" class="data row4 col7" >0.0148</td>
#       <td id="T_6acc3_row4_col8" class="data row4 col8" >0.0490</td>
#     </tr>
#     <tr>
#       <th id="T_6acc3_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_6acc3_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_6acc3_row5_col1" class="data row5 col1" >0.8061</td>
#       <td id="T_6acc3_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_6acc3_row5_col3" class="data row5 col3" >0.8061</td>
#       <td id="T_6acc3_row5_col4" class="data row5 col4" >0.7142</td>
#       <td id="T_6acc3_row5_c

# %%
lgbm = create_model('lightgbm', class_weight='balanced')
# Out:
# <style type="text/css">
# #T_688f0_row10_col0, #T_688f0_row10_col1, #T_688f0_row10_col2, #T_688f0_row10_col3, #T_688f0_row10_col4, #T_688f0_row10_col5, #T_688f0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_688f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_688f0_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_688f0_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_688f0_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_688f0_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_688f0_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_688f0_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_688f0_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_688f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_688f0_row0_col0" class="data row0 col0" >0.7007</td>
#       <td id="T_688f0_row0_col1" class="data row0 col1" >0.7928</td>
#       <td id="T_688f0_row0_col2" class="data row0 col2" >0.7007</td>
#       <td id="T_688f0_row0_col3" class="data row0 col3" >0.7775</td>
#       <td id="T_688f0_row0_col4" class="data row0 col4" >0.7322</td>
#       <td id="T_688f0_row0_col5" class="data row0 col5" >0.2684</td>
#       <td id="T_688f0_row0_col6" class="data row0 col6" >0.2794</td>
#     </tr>
#     <tr>
#       <th id="T_688f0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_688f0_row1_col0" class="data row1 col0" >0.6578</td>
#       <td id="T_688f0_row1_col1" class="data row1 col1" >0.7647</td>
#       <td id="T_688f0_row1_col2" class="data row1 col2" >0.6578</td>
#       <td id="T_688f0_row1_col3" class="data row1 col3" >0.7638</td>
#       <td id="T_688f0_row1_col4" class="data row1 col4" >0.7003</td>
#       <td id="T_688f0_row1_col5" class="data row1 col5" >0.2096</td>
#       <td id="T_688f0_row1_col6" class="data row1 col6" >0.2230</td>
#     </tr>
#     <tr>
#       <th id="T_688f0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_688f0_row2_col0" class="data row2 col0" >0.7064</td>
#       <td id="T_688f0_row2_col1" class="data row2 col1" >0.7833</td>
#       <td id="T_688f0_row2_col2" class="data row2 col2" >0.7064</td>
#       <td id="T_688f0_row2_col3" class="data row2 col3" >0.7797</td>
#       <td id="T_688f0_row2_col4" class="data row2 col4" >0.7360</td>
#       <td id="T_688f0_row2_col5" class="data row2 col5" >0.2803</td>
#       <td id="T_688f0_row2_col6" class="data row2 col6" >0.2917</td>
#     </tr>
#     <tr>
#       <th id="T_688f0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_688f0_row3_col0" class="data row3 col0" >0.6930</td>
#       <td id="T_688f0_row3_col1" class="data row3 col1" >0.7679</td>
#       <td id="T_688f0_row3_col2" class="data row3 col2" >0.6930</td>
#       <td id="T_688f0_row3_col3" class="data row3 col3" >0.7665</td>
#       <td id="T_688f0_row3_col4" class="data row3 col4" >0.7233</td>
#       <td id="T_688f0_row3_col5" class="data row3 col5" >0.2450</td>
#       <td id="T_688f0_row3_col6" class="data row3 col6" >0.2547</td>
#     </tr>
#     <tr>
#       <th id="T_688f0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_688f0_row4_col0" class="data row4 col0" >0.6918</td>
#       <td id="T_688f0_row4_col1" class="data row4 col1" >0.7724</td>
#       <td id="T_688f0_row4_col2" class="data row4 col2" >0.6918</td>
#       <td id="T_688f0_row4_col3" class="data row4 col3" >0.7645</td>
#       <td id="T_688f0_row4_col4" class="data row4 col4" >0.7222</td>
#       <td id="T_688f0_row4_col5" class="data row4 col5" >0.2365</td>
#       <td id="T_688f0_row4_col6" class="data row4 col6" >0.2452</td>
#     </tr>
#     <tr>
#       <th id="T_688f0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_688f0_row5_col0" class="data row5 col0" >0.6918</td>
#       <td id="T_688f0_row5_col1" class="data row5 col1" >0.7931</td>
#       <td id="T_688f0_row5_col2" class="data row5 col2" >0.6918</td>
#       <td id="T_688f0_row5_col3" class="data row5 col3" >0.7661</td>
#       <td id="T_688f0_row5_col4" class="data row5 col4" >0.7227</td>
#       <td id="T_688f0_row5_col5" class="data row5 col5" >0.2399</td>
#       <td id="T_688f0_row5_col6" class="data row5 col6" >0.2492</td>
#     </tr>
#     <tr>
#       <th id="T_688f0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_688f0_row6_col0" class="data row6 col0" >0.6861</td>
#       <td id="T_688f0_row6_col1" class="data row6 col1" >0.7743</td>
#       <td id="T_688f0_row6_col2" class="data row6 col2" >0.6861</td>
#       <td id="T_688f0_row6_col3" class="data row6 col3" >0.7622</td>
#       <td id="T_688f0_row6_col4" class="data row6 col4" >0.7182</td>
#       <td id="T_688f0_row6_col5" class="data row6 col5" >0.2237</td>
#       <td id="T_688f0_row6_col6" class="data row6 col6" >0.2324</td>
#     </tr>
#     <tr>
#       <th id="T_688f0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_688f0_row7_col0" class="data row7 col0" >0.6813</td>
#       <td id="T_688f0_row7_col1" class="data row7 col1" >0.8186</td>
#       <td id="T_688f0_row7_col2" class="data row7 col2" >0.6813</td>
#       <td id="T_688f0_row7_col3" class="data row7 col3" >0.7871</td>
#       <td id="T_688f0_row7_col4" class="data row7 col4" >0.7222</td>
#       <td id="T_688f0_row7_col5" class="data row7 col5" >0.2696</td>
#       <td id="T_688f0_row7_col6" class="data row7 col6" >0.2875</td>
#     </tr>
#     <tr>
#       <th id="T_688f0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_688f0_row8_col0" class="data row8 col0" >0.7013</td>
#       <td id="T_688f0_row8_col1" class="data row8 col1" >0.7766</td>
#       <td id="T_688f0_row8_col2" class="data row8 col2" >0.7013</td>
#       <td id="T_688f0_row8_col3" class="data row8 col3" >0.7786</td>
#       <td id="T_688f0_row8_col4" class="data row8 col4" >0.7322</td>
#       <td id="T_688f0_row8_col5" class="data row8 col5" >0.2727</td>
#       <td id="T_688f0_row8_col6" class="data row8 col6" >0.2851</td>
#     </tr>
#     <tr>
#       <th id="T_688f0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_688f0_row9_col0" class="data row9 col0" >0.6966</td>
#       <td id="T_688f0_row9_col1" class="data row9 col1" >0.7611</td>
#       <td id="T_688f0_row9_col2" class="data row9 col2" >0.6966</td>
#       <td id="T_688f0_row9_col3" class="data row9 col3" >0.7565</td>
#       <td id="T_688f0_row9_col4" class="data row9 col4" >0.7224</td>
#       <td id="T_688f0_row9_col5" class="data row9 col5" >0.2218</td>
#       <td id="T_688f0_row9_col6" class="data row9 col6" >0.2279</td>
#     </tr>
#     <tr>
#       <th id="T_688f0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_688f0_row10_col0" class="data row10 col0" >0.6907</td>
#       <td id="T_688f0_row10_col1" class="data row10 col1" >0.7805</td>
#       <td id="T_688f0_row10_col2" class="data row10 col2" >0.6907</td>
#       <td id="T_688f0_row10_col3" class="data row10 col3" >0.7703</td>
#       <td id="T_688f0_row10_col4" class="data row10 col4" >0.7232</td>
#       <td id="T_688f0_row10_col5" class="data row10 col5" >0.2468</td>
#       <td id="T_688f0_row10_col6" class="data row10 col6" >0.2576</td>
#     </tr>
#     <tr>
#       <th id="T_688f0_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_688f0_row11_col0" class="data row11 col0" >0.0130</td>
#       <td id="T_688f0_row11_col1" class="data row11 col1" >0.0163</td>
#       <td id="T_688f0_row11_col2" class="data row11 col2" >0.0130</td>
#       <td id="T_688f0_row11_col3" class="data row11 col3" >0.0093</td>
#       <td id="T_688f0_row11_col4

# %%
tuned_lgbm = tune_model(lgbm, optimize='F1')
# Out:
# <style type="text/css">
# #T_168b6_row10_col0, #T_168b6_row10_col1, #T_168b6_row10_col2, #T_168b6_row10_col3, #T_168b6_row10_col4, #T_168b6_row10_col5, #T_168b6_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_168b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_168b6_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_168b6_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_168b6_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_168b6_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_168b6_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_168b6_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_168b6_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_168b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_168b6_row0_col0" class="data row0 col0" >0.7493</td>
#       <td id="T_168b6_row0_col1" class="data row0 col1" >0.7562</td>
#       <td id="T_168b6_row0_col2" class="data row0 col2" >0.7493</td>
#       <td id="T_168b6_row0_col3" class="data row0 col3" >0.7493</td>
#       <td id="T_168b6_row0_col4" class="data row0 col4" >0.7493</td>
#       <td id="T_168b6_row0_col5" class="data row0 col5" >0.2378</td>
#       <td id="T_168b6_row0_col6" class="data row0 col6" >0.2378</td>
#     </tr>
#     <tr>
#       <th id="T_168b6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_168b6_row1_col0" class="data row1 col0" >0.7150</td>
#       <td id="T_168b6_row1_col1" class="data row1 col1" >0.7373</td>
#       <td id="T_168b6_row1_col2" class="data row1 col2" >0.7150</td>
#       <td id="T_168b6_row1_col3" class="data row1 col3" >0.7350</td>
#       <td id="T_168b6_row1_col4" class="data row1 col4" >0.7245</td>
#       <td id="T_168b6_row1_col5" class="data row1 col5" >0.1838</td>
#       <td id="T_168b6_row1_col6" class="data row1 col6" >0.1845</td>
#     </tr>
#     <tr>
#       <th id="T_168b6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_168b6_row2_col0" class="data row2 col0" >0.7302</td>
#       <td id="T_168b6_row2_col1" class="data row2 col1" >0.7396</td>
#       <td id="T_168b6_row2_col2" class="data row2 col2" >0.7302</td>
#       <td id="T_168b6_row2_col3" class="data row2 col3" >0.7338</td>
#       <td id="T_168b6_row2_col4" class="data row2 col4" >0.7319</td>
#       <td id="T_168b6_row2_col5" class="data row2 col5" >0.1901</td>
#       <td id="T_168b6_row2_col6" class="data row2 col6" >0.1902</td>
#     </tr>
#     <tr>
#       <th id="T_168b6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_168b6_row3_col0" class="data row3 col0" >0.7531</td>
#       <td id="T_168b6_row3_col1" class="data row3 col1" >0.7355</td>
#       <td id="T_168b6_row3_col2" class="data row3 col2" >0.7531</td>
#       <td id="T_168b6_row3_col3" class="data row3 col3" >0.7505</td>
#       <td id="T_168b6_row3_col4" class="data row3 col4" >0.7517</td>
#       <td id="T_168b6_row3_col5" class="data row3 col5" >0.2387</td>
#       <td id="T_168b6_row3_col6" class="data row3 col6" >0.2388</td>
#     </tr>
#     <tr>
#       <th id="T_168b6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_168b6_row4_col0" class="data row4 col0" >0.7490</td>
#       <td id="T_168b6_row4_col1" class="data row4 col1" >0.7531</td>
#       <td id="T_168b6_row4_col2" class="data row4 col2" >0.7490</td>
#       <td id="T_168b6_row4_col3" class="data row4 col3" >0.7496</td>
#       <td id="T_168b6_row4_col4" class="data row4 col4" >0.7493</td>
#       <td id="T_168b6_row4_col5" class="data row4 col5" >0.2357</td>
#       <td id="T_168b6_row4_col6" class="data row4 col6" >0.2357</td>
#     </tr>
#     <tr>
#       <th id="T_168b6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_168b6_row5_col0" class="data row5 col0" >0.7538</td>
#       <td id="T_168b6_row5_col1" class="data row5 col1" >0.7339</td>
#       <td id="T_168b6_row5_col2" class="data row5 col2" >0.7538</td>
#       <td id="T_168b6_row5_col3" class="data row5 col3" >0.7539</td>
#       <td id="T_168b6_row5_col4" class="data row5 col4" >0.7537</td>
#       <td id="T_168b6_row5_col5" class="data row5 col5" >0.2446</td>
#       <td id="T_168b6_row5_col6" class="data row5 col6" >0.2447</td>
#     </tr>
#     <tr>
#       <th id="T_168b6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_168b6_row6_col0" class="data row6 col0" >0.7347</td>
#       <td id="T_168b6_row6_col1" class="data row6 col1" >0.7475</td>
#       <td id="T_168b6_row6_col2" class="data row6 col2" >0.7347</td>
#       <td id="T_168b6_row6_col3" class="data row6 col3" >0.7426</td>
#       <td id="T_168b6_row6_col4" class="data row6 col4" >0.7386</td>
#       <td id="T_168b6_row6_col5" class="data row6 col5" >0.2076</td>
#       <td id="T_168b6_row6_col6" class="data row6 col6" >0.2078</td>
#     </tr>
#     <tr>
#       <th id="T_168b6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_168b6_row7_col0" class="data row7 col0" >0.7376</td>
#       <td id="T_168b6_row7_col1" class="data row7 col1" >0.7689</td>
#       <td id="T_168b6_row7_col2" class="data row7 col2" >0.7376</td>
#       <td id="T_168b6_row7_col3" class="data row7 col3" >0.7425</td>
#       <td id="T_168b6_row7_col4" class="data row7 col4" >0.7400</td>
#       <td id="T_168b6_row7_col5" class="data row7 col5" >0.2150</td>
#       <td id="T_168b6_row7_col6" class="data row7 col6" >0.2151</td>
#     </tr>
#     <tr>
#       <th id="T_168b6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_168b6_row8_col0" class="data row8 col0" >0.7433</td>
#       <td id="T_168b6_row8_col1" class="data row8 col1" >0.7302</td>
#       <td id="T_168b6_row8_col2" class="data row8 col2" >0.7433</td>
#       <td id="T_168b6_row8_col3" class="data row8 col3" >0.7396</td>
#       <td id="T_168b6_row8_col4" class="data row8 col4" >0.7412</td>
#       <td id="T_168b6_row8_col5" class="data row8 col5" >0.2020</td>
#       <td id="T_168b6_row8_col6" class="data row8 col6" >0.2022</td>
#     </tr>
#     <tr>
#       <th id="T_168b6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_168b6_row9_col0" class="data row9 col0" >0.7500</td>
#       <td id="T_168b6_row9_col1" class="data row9 col1" >0.7312</td>
#       <td id="T_168b6_row9_col2" class="data row9 col2" >0.7500</td>
#       <td id="T_168b6_row9_col3" class="data row9 col3" >0.7317</td>
#       <td id="T_168b6_row9_col4" class="data row9 col4" >0.7403</td>
#       <td id="T_168b6_row9_col5" class="data row9 col5" >0.1846</td>
#       <td id="T_168b6_row9_col6" class="data row9 col6" >0.1855</td>
#     </tr>
#     <tr>
#       <th id="T_168b6_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_168b6_row10_col0" class="data row10 col0" >0.7416</td>
#       <td id="T_168b6_row10_col1" class="data row10 col1" >0.7433</td>
#       <td id="T_168b6_row10_col2" class="data row10 col2" >0.7416</td>
#       <td id="T_168b6_row10_col3" class="data row10 col3" >0.7429</td>
#       <td id="T_168b6_row10_col4" class="data row10 col4" >0.7420</td>
#       <td id="T_168b6_row10_col5" class="data row10 col5" >0.2140</td>
#       <td id="T_168b6_row10_col6" class="data row10 col6" >0.2142</td>
#     </tr>
#     <tr>
#       <th id="T_168b6_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_168b6_row11_col0" class="data row11 col0" >0.0117</td>
#       <td id="T_168b6_row11_col1" class="data row11 col1" >0.0120</td>
#       <td id="T_168b6_row11_col2" class="data row11 col2" >0.0117</td>
#       <td id="T_168b6_row11_col3" class="data row11 col3" >0.0074</td>
#       <td id="T_168b6_row11_col4

# %%
final_model = finalize_model(tuned_lgbm)
prediction = predict_model(final_model, data = X_test)
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1

# %%
prediction
# Out:
#        isSchool  rental_count  return_count     apart  closest_hospital_dist  \
# 38207         0      0.000000      0.000000  0.000000               5.325478
# 34015         0      0.000000      0.000000  0.000000               5.086802
# 20315         0      3.559028      3.605673  0.000000               3.972599
# 32199         0      0.000000      0.000000  0.000000               4.434495
# 29840         0      0.000000      0.000000  7.850103               4.027646
# ...         ...           ...           ...       ...                    ...
# 41569         0      0.000000      0.000000  0.000000               4.783676
# 22776         0      0.000000      0.000000  0.000000               3.764289
# 26942         0      0.000000      0.000000  7.126891               5.059654
# 31596         0      4.559633      4.548770  5.891644               2.166850
# 22167         0      0.000000      0.000000  0.000000               5.406640
#
#        closest_convenience_dist  closest_culture_dist   age_20s   age_30s  \
# 38207                  4.627883              6.015660  8.276779  8.681676
# 34015                  3.935616              5.987284  8.486584  8.766016
# 20315                  3.193857              5.530240  7.868601  7.641568
# 32199                  4.113351              6.348045  8.328084  8.386347
# 29840                  4.496809              6.367069  7.717233  8.243472
# ...                         ...                   ...       ...       ...
# 41569                  4.556271              6.712779  7.117584  7.240508
# 22776                  3.869840              5.768969  7.857319  7.983320
# 26942                  4.032720              6.501971  8.422400  8.412317
# 31596                  2.288287              5.934356  8.995362  8.950693
# 22167                  3.831243              3.894558  8.902174  8.228725
#
#         age_40s  ...  subway_avg_alight     area20     area30     area40  \
# 38207  8.432479  ...                0.0  11.440591  11.843297  11.651719
# 34015  8.777035  ...                0.0  12.414078  12.633709  12.621968
# 20315  7.488942  ...                0.0  12.223945  12.231263  12.244367
# 32199  8.454794  ...                0.0  12.411438  12.528260  12.538799
# 29840  8.305729  ...                0.0   0.000000   0.000000   0.000000
# ...         ...  ...                ...        ...        ...        ...
# 41569  7.263411  ...                0.0   0.000000   0.000000   0.000000
# 22776  8.158035  ...                0.0   9.822779  10.120211  10.381793
# 26942  8.552222  ...                0.0   0.000000   0.000000   0.000000
# 31596  8.692975  ...                0.0  12.733198  12.722761  12.550138
# 22167  8.120695  ...                0.0  12.870352  12.086361  11.915773
#
#        wp_area20  wp_area30  wp_area40  isCommercial  prediction_label  \
# 38207   3.795489   4.430817   4.471639             1                 0
# 34015   6.658653   6.378850   6.437352             1                 0
# 20315   3.481240   3.778491   3.921973             1                 0
# 32199   4.200954   4.943427   5.154736             1                 0
# 29840   0.000000   0.000000   0.000000             0                 0
# ...          ...        ...        ...           ...               ...
# 41569   0.000000   0.000000   0.000000             1                 1
# 22776   2.505526   2.602690   2.740840             1                 1
# 26942   0.000000   0.000000   0.000000             1                 1
# 31596   7.326795   7.761639   7.744245             1                 1
# 22167   3.341094   3.917011   3.970292             1                 0
#
#        prediction_score
# 38207            0.8105
# 34015            0.9940
# 20315            0.4874
# 32199            0.6995
# 29840            0.9697
# ...                 ...
# 41569            0.5741
# 22776            0.6139
# 26942            0.5901
# 31596            0.9268
# 22167            0.8584
#
# [8818 rows x 29 columns]

# %%
from sklearn.metrics import f1_score
f1 = f1_score(y_test, prediction['prediction_label'], average ="weighted")
print(f"f1_score: {f1:.4f}")
# Out:
# f1_score: 0.7155

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 혼동 행렬 계산
cm = confusion_matrix(y_test, prediction['prediction_label'])

# 혼동 행렬 시각화
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=['Class 0', 'Class 1', 'Class 2'], yticklabels=['Class 0', 'Class 1', 'Class 2'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
model_feature_importance = final_model.feature_importances_

# 중요도 값과 feature 이름을 함께 출력
features = get_config('X_train').columns
importance_df = pd.DataFrame({'Feature': features, 'Importance': model_feature_importance})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=importance_df)
plt.title('Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %%
X_test_transformed = final_model[:-1].transform(X_test)

explainer = shap.Explainer(final_model.steps[-1][1])
shap_values = explainer(X_test_transformed)

for class_idx in range(shap_values.values.shape[2]):
    print(f"클래스 {class_idx}")
    plt.figure(figsize=(8, 4))
    shap.summary_plot(shap_values.values[:, :, class_idx], X_test_transformed)
# Out:
# 클래스 0
# 클래스 1
# 클래스 2

# %%
# 모델 저장
save_model(final_model, 'models/domain_specific_model_3')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['isSchool', 'rental_count',
#                                               'return_count', 'apart',
#                                               'closest_hospital_dist',
#                                               'closest_convenience_dist',
#                                               'closest_culture_dist', 'age_20s',
#                                               'age_30s', 'age_40s',
#                                               'crosswalk_count',
#                                               'closest_cross_dist', 'bus_count',
#                                               'closest_bus_dist', 'subway_count',
#                                               'clos...
#                                  boosting_type='gbdt', class_weight='balanced',
#                                  colsample_bytree=1.0, feature_fraction=0.8,
#                                  importance_type='split', learning_rate=0.5,
#                                  max_depth=-1, min_child_samples=11,
#                                  min_child_weight=0.001, min_split_gain=0.3,
#                                  n_estimators=250, n_jobs=-1, num_leaves=30,
#                                  objective=None, random_state=42, reg_alpha=0.7,
#                                  reg_lambda=2, subsample=1.0,
#                                  subsample_for_bin=200000, subsample_freq=0))],
#           verbose=False),
#  'domain_specific_model_3.pkl')
